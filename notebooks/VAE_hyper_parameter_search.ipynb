# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import (
    layers,
    models,
    datasets,
    callbacks,
    losses,
    optimizers,
    metrics,
)
import keras
from tensorflow.keras.callbacks import TensorBoard
from tensorboard.plugins.hparams import api as hp
from tensorflow import keras
from keras.layers import Input, Dense, Lambda
from itertools import product

from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
train_data = pd.read_csv("../data/interim/cut_data.csv")
val_data = pd.read_csv("../data/interim/split/sorted_val_data_mm.csv")

# %%
train_data_array = train_data.values
val_data_array = val_data.values

# %%
# https://www.tensorflow.org/tensorboard/hyperparameter_tuning_with_hparams

list_of_layers = [64, 128, 256, 512]
list_of_latent = [2, 4, 16, 32, 64]
list_of_boolean = [True, False]
list_of_kl_loss_rate =  [0.0001, 0.1, 1.0, 10.0]
list_of_binary_weight =  [0.1, 1.0, 10.0]


hyperparameters_product = product(
    list_of_layers, list_of_layers, list_of_latent,
    list_of_kl_loss_rate, list_of_binary_weight, list_of_boolean, list_of_boolean, 
)
# list_of_drop_out,
# Calculate the total number of combinations
number_of_combinations = len(list(hyperparameters_product))

print("Total number of combinations:", number_of_combinations)
# Out:
# Total number of combinations: 3840

# %%
HP_NUM_embedded = hp.HParam("num_embedded", hp.Discrete(list_of_latent))
HP_NUM_UNITS = hp.HParam("num_units", hp.Discrete(list_of_layers))
HP_NUM_UNITS1 = hp.HParam("num_units1", hp.Discrete(list_of_layers))
#HP_BOOL_BATCH = hp.HParam("bool_batch", hp.Discrete(list_of_boolean))
HP_BOOL_2_LAYER = hp.HParam("bool_layer_2", hp.Discrete(list_of_boolean))
HP_BOOL_4_LAYER = hp.HParam("bool_layer_4", hp.Discrete(list_of_boolean))
# HP_DROP_OUT_BOOL = hp.HParam("drop_out", hp.Discrete(list_of_boolean))
# HP_DROP_OUT_RATE = hp.HParam("drop_out_rate", hp.Discrete(list_of_drop_out))


HP_KL_LOSS_RATE = hp.HParam("KL_LOSS_RATE", hp.Discrete(list_of_kl_loss_rate))
HP_BINARY_WEIGHT = hp.HParam("BINARY_WEIGHT", hp.Discrete(list_of_binary_weight))

VAL_LOSS = "val_loss"
VAL_MEAN_BINARY_VALUE = "val_mean_binary_value"
VAL_MEAN_CONT_DIFF = "val_mean_abs_diff_cont"
VAL_MEAN_CLASS_DIFF = "val_mean_abs_diff_class"
VAL_MEAN_KL_LOSS = "val_mean_kl_loss"
VAL_MEAN_KL_DIV = "val_mean_kl_div"
VAL_LOSS_SAMPLE = "val_loss_sample"
VAL_MEAN_BINARY_VALUE_SAMPLE = "val_mean_binary_value_sample"
VAL_MEAN_CONT_DIFF_SAMPLE = "val_mean_abs_diff_cont_sample"
VAL_MEAN_CLASS_DIFF_SAMPLE = "val_mean_abs_diff_class_sample"
VAL_MEAN_KL_DIV_SAMPLE = "val_mean_kl_div_sample"


# the other one was stored at logs/hparam_tuning_vae_from_base1
path = "logs/hparam_tuning_vae_extended_corrected/"


with tf.summary.create_file_writer(path).as_default():
    hp.hparams_config(
        hparams=[
            HP_NUM_embedded,
            # HP_BOOL_BATCH,
            HP_BOOL_2_LAYER,
            HP_BOOL_4_LAYER,
            HP_NUM_UNITS,
            HP_NUM_UNITS1,
            # HP_DROP_OUT_BOOL,
            # HP_DROP_OUT_RATE,
            HP_KL_LOSS_RATE,
            HP_BINARY_WEIGHT,
        ],

        metrics=[
            hp.Metric(VAL_LOSS, display_name="val_loss"),
            hp.Metric(VAL_MEAN_BINARY_VALUE, display_name="val_mean_binary_value",),
            hp.Metric(VAL_MEAN_CONT_DIFF, display_name="val_mean_abs_diff_cont"),
            hp.Metric(VAL_MEAN_CLASS_DIFF, display_name="val_mean_abs_diff_class"),
            hp.Metric(VAL_MEAN_KL_LOSS, display_name= "val_mean_kl_loss"),
            hp.Metric(VAL_MEAN_KL_DIV, display_name = "val_mean_kl_div"),
            hp.Metric(VAL_LOSS_SAMPLE, display_name="val_loss_sample"),
            hp.Metric(VAL_MEAN_BINARY_VALUE_SAMPLE, display_name="val_mean_binary_value_sample"),
            hp.Metric(VAL_MEAN_CONT_DIFF_SAMPLE, display_name="val_mean_abs_diff_cont_sample"),
            hp.Metric(VAL_MEAN_CLASS_DIFF_SAMPLE, display_name="val_mean_abs_diff_class_sample"),
            hp.Metric(VAL_MEAN_KL_DIV_SAMPLE, display_name="val_mean_kl_div_sample"),  
        ],
    )

# %%
def build_model(hparams):
    class Sampling(keras.layers.Layer):
        def call(self, inputs):
            z_mean, z_log_var = inputs
            batch = tf.shape(z_mean)[0]
            dim = tf.shape(z_mean)[1]
            # epsilon = gumbel_sample((batch, dim))
            epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
            return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    latent_dim = hparams[HP_NUM_embedded]
    encoder_inputs = Input(shape=(31), name="input_layer")

    x = Dense(hparams[HP_NUM_UNITS], activation="relu", name="h1")(encoder_inputs)

    #if hparams[HP_BOOL_BATCH] == True:
    x = layers.BatchNormalization()(x)
    # if hparams[HP_DROP_OUT_BOOL] == True:
    #     x = layers.Dropout(0.3)(x)

    if hparams[HP_BOOL_2_LAYER] == True:
        x = Dense(hparams[HP_NUM_UNITS1], activation="relu", name="h2")(x)
        # Split x3 into two halves
        half_size = hparams[HP_NUM_UNITS1] // 2
    else:
        half_size = hparams[HP_NUM_UNITS] // 2

    x1_first_half = Lambda(lambda x: x[:, :half_size], name="select_z_mean")(x)
    x1_second_half = Lambda(lambda x: x[:, half_size:], name="select_z_var")(x)

    z_mean = Dense(latent_dim, name="z_mean")(x1_first_half)
    z_log_var = Dense(latent_dim, name="z_log_var")(x1_second_half)
    z = Sampling(name="Sampling")([z_mean, z_log_var])

    encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

    # Decoder
    latent_inputs = keras.Input(shape=(latent_dim,))
    x = Dense(hparams[HP_NUM_UNITS1], activation="relu", name="h4")(latent_inputs)

    #if hparams[HP_BOOL_BATCH] == True:
    x = layers.BatchNormalization()(x)
    # if hparams[HP_DROP_OUT_BOOL] == True:
    #     x = layers.Dropout(0.3)(x)

    if hparams[HP_BOOL_4_LAYER] == True:
        x = Dense(hparams[HP_NUM_UNITS], activation="relu", name="h5")(x)
    
    cont_decoder_outputs = Dense(30, activation="linear", name="cont_decoder_output")(x)
    class_decoder_output = Dense(1, activation="sigmoid", name="classification_output")(x)
    decoder = keras.Model(
        latent_inputs, [cont_decoder_outputs, class_decoder_output], name="decoder"
    )

    class VAE(keras.Model):
        def __init__(self, encoder, decoder, **kwargs):
            super().__init__(**kwargs)
            # Trackers for the data-data-generation process
            self.encoder = encoder
            self.decoder = decoder
            self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
            self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
            self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
            self.reconstruction_loss_class_tracker = keras.metrics.Mean(name="reconstruction_loss_class")
            self.mean_abs_diff_cont_tracker = keras.metrics.Mean(name="mean_abs_diff_cont")
            self.mean_abs_diff_class_tracker = keras.metrics.Mean(name="mean_abs_diff_class")
            self.mean_binary_tracker = keras.metrics.Mean(name="mean_binary_value")
            self.kl_div_tracker = keras.metrics.Mean(name="kl_divergence")

            # Trackers for the sampling-data-generation process
            self.total_loss_tracker_sample = keras.metrics.Mean(name="total_loss_sample")
            self.reconstruction_loss_tracker_sample = keras.metrics.Mean(name="reconstruction_loss_sample")
            self.reconstruction_loss_class_tracker_sample = keras.metrics.Mean(name="reconstruction_loss_class_sample")
            self.mean_abs_diff_cont_tracker_sample = keras.metrics.Mean(name="mean_abs_diff_cont_sample")
            self.mean_abs_diff_class_tracker_sample = keras.metrics.Mean(name="mean_abs_diff_class_sample")
            self.mean_binary_tracker_sample = keras.metrics.Mean(name="mean_binary_value_sample")
            self.kl_div_tracker_sample = keras.metrics.Mean(name="kl_divergence_sample")

        @property
        def metrics(self):
            return [
                self.total_loss_tracker,
                self.reconstruction_loss_tracker,
                self.kl_loss_tracker,
                self.reconstruction_loss_class_tracker,
            ]

        def train_step(self, data):
            with tf.GradientTape() as tape:
                z_mean, z_log_var, z = self.encoder(data)

                # latent_vectors = np.random.normal(scale=1, size=(32, latent_dim))
                # reconstruction_cont, reconstruction_class = self.decoder(latent_vectors)
                reconstruction_cont, reconstruction_class = self.decoder(z)

                data_cont = data[
                    :, :30
                ]  # Assuming the first 4 columns are for continuous variables
                data_class = data[:, 30:]  # Assuming the last column is for classification

                # Reconstruction loss for continuous outputs
                reconstruction_loss_cont = keras.losses.mean_squared_error(
                    data_cont, reconstruction_cont
                )

                # Reconstruction loss for classification output
                reconstruction_loss_class = keras.losses.binary_crossentropy(
                    data_class, reconstruction_class
                )

                kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
                kl_loss = tf.reduce_mean(kl_loss, axis=1)

                kl_div = tf.keras.losses.KLDivergence()(data_cont, reconstruction_cont)

                # Combine losses
                total_loss = (
                    reconstruction_loss_cont
                    + hparams[HP_BINARY_WEIGHT] * reconstruction_loss_class
                    + hparams[HP_KL_LOSS_RATE] * kl_loss
                )

            grads = tape.gradient(total_loss, self.trainable_weights)
            self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
            self.total_loss_tracker.update_state(total_loss)
            self.reconstruction_loss_tracker.update_state(reconstruction_loss_cont)
            self.kl_loss_tracker.update_state(kl_loss)
            self.reconstruction_loss_class_tracker.update_state(reconstruction_loss_class)
            self.kl_div_tracker.update_state(kl_div)

            return {
                "loss": self.total_loss_tracker.result(),
                "reconstruction_loss_cont": self.reconstruction_loss_tracker.result(),
                "reconstruction_loss_class": self.reconstruction_loss_class_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
                "kl_div": self.kl_div_tracker.result(),
            }

        def test_step(self, data):
            """Step run during validation."""
            if isinstance(data, tuple):
                data = data[0]  # Unpack the tuple and take the input data

            data_cont = data[:, :30]
            data_class = data[:, 30:]

            # The whole teststep for the data creation with data
            z_mean, z_log_var, z = self.encoder(data)

            reconstruction_cont, reconstruction_class = self.decoder(z)

            reconstruction_loss_cont = keras.losses.mean_squared_error(
                data_cont, reconstruction_cont
            )

            # Reconstruction loss for classification output
            reconstruction_loss_class = keras.losses.binary_crossentropy(
                data_class, reconstruction_class
            )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(kl_loss, axis=1)

            # Combine losses
            total_loss = (reconstruction_loss_cont
                    + hparams[HP_BINARY_WEIGHT] * reconstruction_loss_class
                    + hparams[HP_KL_LOSS_RATE] * kl_loss)

            # Compute mean absolute differences and mean of binary data
            mean_abs_diff_cont = tf.reduce_mean(tf.abs(data_cont - reconstruction_cont))
            mean_binary_value = tf.reduce_mean(
                tf.cast(reconstruction_class >= 0.5, tf.float32)
            )
            mean_abs_diff_class = tf.reduce_mean(tf.abs(data_class - mean_binary_value))

            # Compute the KL Div between original data and reconstructed
            kl_div = tf.keras.losses.KLDivergence()(data_cont, reconstruction_cont)

            # Whole test step for data creation with sampeling
            latent_vectors = np.random.normal(scale=1, size=(32, latent_dim))
            reconstruction_cont_sample, reconstruction_class_sample = self.decoder(
                latent_vectors
            )

            reconstruction_loss_cont_sample = keras.losses.mean_squared_error(
                data_cont, reconstruction_cont_sample
            )

            # Reconstruction loss for classification output
            reconstruction_loss_class_sample = keras.losses.binary_crossentropy(
                data_class, reconstruction_class_sample
            )

            # Combine losses
            total_loss_sample = (reconstruction_loss_cont_sample
                + hparams[HP_BINARY_WEIGHT] * reconstruction_loss_class_sample
                + hparams[HP_KL_LOSS_RATE] * kl_loss)

            # Compute mean absolute differences and mean of binary data
            mean_abs_diff_cont_sample = tf.reduce_mean(
                tf.abs(data_cont - reconstruction_cont_sample)
            )
            mean_binary_value_sample = tf.reduce_mean(
                tf.cast(reconstruction_class_sample >= 0.5, tf.float32)
            )
            mean_abs_diff_class_sample = tf.reduce_mean(
                tf.abs(data_class - mean_binary_value_sample)
            )

            # Compute the KL Div between original data and reconstructed
            kl_div_sample = tf.keras.losses.KLDivergence()(
                data_cont, reconstruction_cont_sample
            )

            # Update metrics
            # Update for data creation process
            self.total_loss_tracker.update_state(total_loss)
            self.reconstruction_loss_tracker.update_state(reconstruction_loss_cont)
            self.kl_loss_tracker.update_state(kl_loss)
            self.reconstruction_loss_class_tracker.update_state(reconstruction_loss_class)
            self.mean_abs_diff_cont_tracker.update_state(mean_abs_diff_cont)
            self.mean_abs_diff_class_tracker.update_state(mean_abs_diff_class)
            self.mean_binary_tracker.update_state(mean_binary_value)
            self.kl_div_tracker.update_state(kl_div)

            # Update for sampling creation process
            self.total_loss_tracker_sample.update_state(total_loss_sample)
            self.reconstruction_loss_tracker_sample.update_state(
                reconstruction_loss_cont_sample
            )
            self.reconstruction_loss_class_tracker_sample.update_state(
                reconstruction_loss_class_sample
            )
            self.mean_abs_diff_cont_tracker_sample.update_state(mean_abs_diff_cont_sample)
            self.mean_abs_diff_class_tracker_sample.update_state(mean_abs_diff_class_sample)
            self.mean_binary_tracker_sample.update_state(mean_binary_value_sample)
            self.kl_div_tracker_sample.update_state(kl_div_sample)

            # Return a dict mapping metric names to current value
            return {
                "loss": self.total_loss_tracker.result(),
                "reconstruction_loss_cont": self.reconstruction_loss_tracker.result(),
                "reconstruction_loss_class": self.reconstruction_loss_class_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
                "mean_abs_diff_cont": self.mean_abs_diff_cont_tracker.result(),
                "mean_abs_diff_class": self.mean_abs_diff_class_tracker.result(),
                "mean_binary_value": self.mean_binary_tracker.result(),
                "kl_div": self.kl_div_tracker.result(),

                # returning the sampling process testing
                "loss_sample": self.reconstruction_loss_tracker_sample.result(),
                "reconstruction_loss_cont_sample": self.reconstruction_loss_tracker_sample.result(),
                "reconstruction_loss_class_sample": self.reconstruction_loss_class_tracker_sample.result(),
                "mean_abs_diff_cont_sample": self.mean_abs_diff_cont_tracker_sample.result(),
                "mean_abs_diff_class_sample": self.mean_abs_diff_class_tracker_sample.result(),
                "mean_binary_value_sample": self.mean_binary_tracker_sample.result(),
                "kl_div_sample": self.kl_div_tracker_sample.result(),
            }

    log_dir = "logs/"
    vae = VAE(encoder, decoder)
    optimizer = optimizers.Adam()
    vae.compile(optimizer=optimizer)
    hist = vae.fit(
        train_data_array,
        epochs=1,
        batch_size=32,
        validation_data=(val_data_array, None),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),  # log metrics
            hp.KerasCallback(log_dir, hparams),  # log hparams
        ],
    )
    return (
        hist.history["val_loss"],
        hist.history["val_mean_binary_value"],
        hist.history["val_mean_abs_diff_cont"],
        hist.history["val_mean_abs_diff_class"],
        hist.history["val_kl_loss"],
        hist.history["val_kl_div"],
        hist.history["val_loss_sample"],
        hist.history["val_mean_binary_value_sample"],
        hist.history["val_mean_abs_diff_cont_sample"],
        hist.history["val_mean_abs_diff_class_sample"],
        hist.history["val_kl_div_sample"],
    )

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        (
            val_loss,
            val_mean,
            val_mean_diff_cont,
            val_mean_diff_class,
            val_kl_loss,
            val_kl_div,
            val_loss_sample,
            val_mean_sample,
            val_mean_abs_diff_cont_sample,
            val_mean_abs_diff_class_sample,
            val_kl_div_sample,
        ) = build_model(
            hparams
        )  # Returns both val_loss and val_mean

        tf.summary.scalar(VAL_LOSS, val_loss[0], step=1)
        tf.summary.scalar(VAL_MEAN_BINARY_VALUE, val_mean[0], step=1)
        tf.summary.scalar(VAL_MEAN_CONT_DIFF , val_mean_diff_cont[0], step=1)
        tf.summary.scalar(VAL_MEAN_CLASS_DIFF, val_mean_diff_class[0], step=1)
        tf.summary.scalar(VAL_MEAN_KL_LOSS, val_kl_loss[0], step=1)
        tf.summary.scalar(VAL_MEAN_KL_DIV, val_kl_div[0], step=1)
        tf.summary.scalar(VAL_LOSS_SAMPLE, val_loss_sample[0], step=1)
        tf.summary.scalar(VAL_MEAN_BINARY_VALUE_SAMPLE, val_mean_sample[0], step=1)
        tf.summary.scalar(VAL_MEAN_CONT_DIFF_SAMPLE, val_mean_abs_diff_cont_sample[0], step=1)
        tf.summary.scalar(VAL_MEAN_CLASS_DIFF_SAMPLE, val_mean_abs_diff_class_sample[0], step=1)
        tf.summary.scalar(VAL_MEAN_KL_DIV_SAMPLE, val_kl_div_sample[0], step=1)

# %%
import os

# Define the logs directory
logs_dir = path

# Check if the logs directory exists
if os.path.exists(logs_dir):
    # Get a list of all files in the logs directory
    log_files = os.listdir(logs_dir)

    # Filter the list to only include files with the naming convention "run-<number>"
    run_numbers = [
        int(file.split("-")[1]) for file in log_files if file.startswith("run-")
    ]

    # Determine the next run number by finding the maximum run number and incrementing it by 1
    next_run_num = max(run_numbers) + 1 if run_numbers else 0
else:
    # If the logs directory doesn't exist, start from run-0
    next_run_num = 0

print("Next run number:", next_run_num)
# Out:
# Next run number: 0

# %%
session_num = next_run_num

for embedded in HP_NUM_embedded.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for num_units1 in HP_NUM_UNITS1.domain.values:
            for bool_2 in HP_BOOL_2_LAYER.domain.values:
                for bool_4 in HP_BOOL_4_LAYER.domain.values:
                    for beta in HP_KL_LOSS_RATE.domain.values:
                        for binary_value in HP_BINARY_WEIGHT.domain.values:
                            
                            hparams = {
                            HP_NUM_embedded: embedded,
                            HP_NUM_UNITS: num_units,
                            HP_NUM_UNITS1: num_units1,
                            #HP_BOOL_BATCH: bool_batch,
                            HP_BOOL_2_LAYER: bool_2,
                            HP_BOOL_4_LAYER: bool_4,
                            HP_KL_LOSS_RATE: beta,
                            HP_BINARY_WEIGHT: binary_value,
                        }
                            run_name = "run-%d" % session_num
                            print("--- Starting trial: %s" % run_name)
                            print({h.name: hparams[h] for h in hparams})
                            run(
                                path + run_name,
                                hparams,
                            )
                            session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0423 - reconstruction_loss_cont: 0.0307 - reconstruction_loss_class: 0.0378 - kl_loss: 5.7548 - kl_div: 8.0970 - val_loss: 0.0111 - val_reconstruction_loss_cont: 0.0101 - val_reconstruction_loss_class: 0.0042 - val_kl_loss: 5.3583 - val_mean_abs_diff_cont: 0.0421 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.4325 - val_loss_sample: 0.1613 - val_reconstruction_loss_cont_sample: 0.1613 - val_reconstruction_loss_class_sample: 0.3097 - val_mean_abs_diff_cont_sample: 0.3466 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 35.9154
# --- Starting trial: run-1
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.1388 - reconstruction_loss_cont: 0.0436 - reconstruction_loss_class: 0.0316 - kl_loss: 6.1255 - kl_div: 12.3621 - val_loss: 0.0146 - val_reconstruction_loss_cont: 0.0110 - val_reconstruction_loss_class: 0.0030 - val_kl_loss: 6.6653 - val_mean_abs_diff_cont: 0.0447 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.7257 - val_loss_sample: 0.1649 - val_reconstruction_loss_cont_sample: 0.1649 - val_reconstruction_loss_class_sample: 0.2580 - val_mean_abs_diff_cont_sample: 0.3491 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 33.6572
# --- Starting trial: run-2
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.9141 - reconstruction_loss_cont: 0.0599 - reconstruction_loss_class: 0.0315 - kl_loss: 8.5533 - kl_div: 17.6569 - val_loss: 0.0634 - val_reconstruction_loss_cont: 0.0115 - val_reconstruction_loss_class: 0.0051 - val_kl_loss: 6.7625 - val_mean_abs_diff_cont: 0.0492 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.6226 - val_loss_sample: 0.2033 - val_reconstruction_loss_cont_sample: 0.2033 - val_reconstruction_loss_class_sample: 0.3570 - val_mean_abs_diff_cont_sample: 0.3949 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 49.0680
# --- Starting trial: run-3
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0679 - reconstruction_loss_cont: 0.0467 - reconstruction_loss_class: 0.0740 - kl_loss: 0.0101 - kl_div: 11.4942 - val_loss: 0.0119 - val_reconstruction_loss_cont: 0.0106 - val_reconstruction_loss_class: 0.0127 - val_kl_loss: 3.1435e-04 - val_mean_abs_diff_cont: 0.0438 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.8010 - val_loss_sample: 0.0106 - val_reconstruction_loss_cont_sample: 0.0106 - val_reconstruction_loss_class_sample: 0.0129 - val_mean_abs_diff_cont_sample: 0.0432 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.0246
# --- Starting trial: run-4
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.1935 - reconstruction_loss_cont: 0.0500 - reconstruction_loss_class: 0.0453 - kl_loss: 0.1357 - kl_div: 12.9789 - val_loss: 0.0216 - val_reconstruction_loss_cont: 0.0106 - val_reconstruction_loss_class: 0.0098 - val_kl_loss: 0.0118 - val_mean_abs_diff_cont: 0.0453 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.0264 - val_loss_sample: 0.0108 - val_reconstruction_loss_cont_sample: 0.0108 - val_reconstruction_loss_class_sample: 0.0133 - val_mean_abs_diff_cont_sample: 0.0462 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9047
# --- Starting trial: run-5
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 1.2677 - reconstruction_loss_cont: 0.0546 - reconstruction_loss_class: 0.0349 - kl_loss: 1.4179 - kl_div: 16.2467 - val_loss: 0.1166 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0024 - val_kl_loss: 0.8141 - val_mean_abs_diff_cont: 0.0453 - val_mean_abs_diff_class: 0.0024 - val_mean_binary_value: 9.8204e-04 - val_kl_div: 2.5223 - val_loss_sample: 0.0739 - val_reconstruction_loss_cont_sample: 0.0739 - val_reconstruction_loss_class_sample: 0.1958 - val_mean_abs_diff_cont_sample: 0.1725 - val_mean_abs_diff_class_sample: 0.0639 - val_mean_binary_value_sample: 0.0625 - val_kl_div_sample: 18.7246
# --- Starting trial: run-6
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.0839 - reconstruction_loss_cont: 0.0597 - reconstruction_loss_class: 0.0872 - kl_loss: 6.7535e-04 - kl_div: 16.1561 - val_loss: 0.0123 - val_reconstruction_loss_cont: 0.0108 - val_reconstruction_loss_class: 0.0132 - val_kl_loss: 1.7646e-04 - val_mean_abs_diff_cont: 0.0449 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.4010 - val_loss_sample: 0.0108 - val_reconstruction_loss_cont_sample: 0.0108 - val_reconstruction_loss_class_sample: 0.0131 - val_mean_abs_diff_cont_sample: 0.0446 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9705
# --- Starting trial: run-7
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.2260 - reconstruction_loss_cont: 0.0583 - reconstruction_loss_class: 0.0643 - kl_loss: 0.0017 - kl_div: 14.8025 - val_loss: 0.0240 - val_reconstruction_loss_cont: 0.0110 - val_reconstruction_loss_class: 0.0122 - val_kl_loss: 7.6834e-04 - val_mean_abs_diff_cont: 0.0466 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.3213 - val_loss_sample: 0.0110 - val_reconstruction_loss_cont_sample: 0.0110 - val_reconstruction_loss_class_sample: 0.0124 - val_mean_abs_diff_cont_sample: 0.0466 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.0186
# --- Starting trial: run-8
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 1.5141 - reconstruction_loss_cont: 0.0732 - reconstruction_loss_class: 0.0483 - kl_loss: 0.0975 - kl_div: 19.4621 - val_loss: 0.1339 - val_reconstruction_loss_cont: 0.0113 - val_reconstruction_loss_class: 0.0120 - val_kl_loss: 0.0030 - val_mean_abs_diff_cont: 0.0480 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.9521 - val_loss_sample: 0.0117 - val_reconstruction_loss_cont_sample: 0.0117 - val_reconstruction_loss_class_sample: 0.0123 - val_mean_abs_diff_cont_sample: 0.0504 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9174
# --- Starting trial: run-9
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.1216 - reconstruction_loss_cont: 0.0543 - reconstruction_loss_class: 0.0942 - kl_loss: 9.0818e-04 - kl_div: 14.4009 - val_loss: 0.0135 - val_reconstruction_loss_cont: 0.0110 - val_reconstruction_loss_class: 0.0133 - val_kl_loss: 1.1865e-04 - val_mean_abs_diff_cont: 0.0436 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.1930 - val_loss_sample: 0.0112 - val_reconstruction_loss_cont_sample: 0.0112 - val_reconstruction_loss_class_sample: 0.0134 - val_mean_abs_diff_cont_sample: 0.0445 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9032
# --- Starting trial: run-10
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.2478 - reconstruction_loss_cont: 0.0632 - reconstruction_loss_class: 0.0560 - kl_loss: 0.0010 - kl_div: 17.1747 - val_loss: 0.0262 - val_reconstruction_loss_cont: 0.0107 - val_reconstruction_loss_class: 0.0125 - val_kl_loss: 3.0113e-04 - val_mean_abs_diff_cont: 0.0449 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.6078 - val_loss_sample: 0.0108 - val_reconstruction_loss_cont_sample: 0.0108 - val_reconstruction_loss_class_sample: 0.0123 - val_mean_abs_diff_cont_sample: 0.0451 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.0288
# --- Starting trial: run-11
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 1.7098 - reconstruction_loss_cont: 0.0668 - reconstruction_loss_class: 0.0627 - kl_loss: 0.0016 - kl_div: 18.0685 - val_loss: 0.1372 - val_reconstruction_loss_cont: 0.0106 - val_reconstruction_loss_class: 0.0122 - val_kl_loss: 4.5258e-04 - val_mean_abs_diff_cont: 0.0459 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.6839 - val_loss_sample: 0.0104 - val_reconstruction_loss_cont_sample: 0.0104 - val_reconstruction_loss_class_sample: 0.0127 - val_mean_abs_diff_cont_sample: 0.0456 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8760
# --- Starting trial: run-12
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0400 - reconstruction_loss_cont: 0.0275 - reconstruction_loss_class: 0.0400 - kl_loss: 5.0774 - kl_div: 7.3079 - val_loss: 0.0117 - val_reconstruction_loss_cont: 0.0109 - val_reconstruction_loss_class: 0.0045 - val_kl_loss: 3.8990 - val_mean_abs_diff_cont: 0.0427 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.2621 - val_loss_sample: 0.0689 - val_reconstruction_loss_cont_sample: 0.0689 - val_reconstruction_loss_class_sample: 0.1294 - val_mean_abs_diff_cont_sample: 0.2154 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 9.8156
# --- Starting trial: run-13
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1154 - reconstruction_loss_cont: 0.0429 - reconstruction_loss_class: 0.0263 - kl_loss: 5.1355 - kl_div: 12.1606 - val_loss: 0.0140 - val_reconstruction_loss_cont: 0.0113 - val_reconstruction_loss_class: 0.0023 - val_kl_loss: 3.7112 - val_mean_abs_diff_cont: 0.0507 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.1506 - val_loss_sample: 0.0894 - val_reconstruction_loss_cont_sample: 0.0894 - val_reconstruction_loss_class_sample: 0.2168 - val_mean_abs_diff_cont_sample: 0.2482 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 11.2368
# --- Starting trial: run-14
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.7742 - reconstruction_loss_cont: 0.0697 - reconstruction_loss_class: 0.0247 - kl_loss: 3.9545 - kl_div: 15.3748 - val_loss: 0.0317 - val_reconstruction_loss_cont: 0.0117 - val_reconstruction_loss_class: 0.0020 - val_kl_loss: 2.9871 - val_mean_abs_diff_cont: 0.0495 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.4501 - val_loss_sample: 0.1202 - val_reconstruction_loss_cont_sample: 0.1202 - val_reconstruction_loss_class_sample: 0.2456 - val_mean_abs_diff_cont_sample: 0.2895 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 18.6201
# --- Starting trial: run-15
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0568 - reconstruction_loss_cont: 0.0416 - reconstruction_loss_class: 0.0535 - kl_loss: 0.0029 - kl_div: 11.3452 - val_loss: 0.0129 - val_reconstruction_loss_cont: 0.0114 - val_reconstruction_loss_class: 0.0121 - val_kl_loss: 0.0022 - val_mean_abs_diff_cont: 0.0434 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.7383 - val_loss_sample: 0.0114 - val_reconstruction_loss_cont_sample: 0.0114 - val_reconstruction_loss_class_sample: 0.0126 - val_mean_abs_diff_cont_sample: 0.0433 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.0553
# --- Starting trial: run-16
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1548 - reconstruction_loss_cont: 0.0484 - reconstruction_loss_class: 0.0400 - kl_loss: 0.0252 - kl_div: 13.0885 - val_loss: 0.0227 - val_reconstruction_loss_cont: 0.0107 - val_reconstruction_loss_class: 0.0119 - val_kl_loss: 0.0019 - val_mean_abs_diff_cont: 0.0436 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.9014 - val_loss_sample: 0.0106 - val_reconstruction_loss_cont_sample: 0.0106 - val_reconstruction_loss_class_sample: 0.0128 - val_mean_abs_diff_cont_sample: 0.0430 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8760
# --- Starting trial: run-17
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.9809 - reconstruction_loss_cont: 0.0732 - reconstruction_loss_class: 0.0254 - kl_loss: 0.7364 - kl_div: 17.6926 - val_loss: 0.0662 - val_reconstruction_loss_cont: 0.0132 - val_reconstruction_loss_class: 8.7377e-04 - val_kl_loss: 0.4421 - val_mean_abs_diff_cont: 0.0607 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 2.7382 - val_loss_sample: 0.0227 - val_reconstruction_loss_cont_sample: 0.0227 - val_reconstruction_loss_class_sample: 0.2665 - val_mean_abs_diff_cont_sample: 0.0985 - val_mean_abs_diff_class_sample: 0.1885 - val_mean_binary_value_sample: 0.1875 - val_kl_div_sample: 1.6158
# --- Starting trial: run-18
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0634 - reconstruction_loss_cont: 0.0395 - reconstruction_loss_class: 0.0621 - kl_loss: 0.0016 - kl_div: 10.4088 - val_loss: 0.0133 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0128 - val_kl_loss: 9.1511e-04 - val_mean_abs_diff_cont: 0.0420 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.6200 - val_loss_sample: 0.0111 - val_reconstruction_loss_cont_sample: 0.0111 - val_reconstruction_loss_class_sample: 0.0125 - val_mean_abs_diff_cont_sample: 0.0423 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9796
# --- Starting trial: run-19
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1273 - reconstruction_loss_cont: 0.0453 - reconstruction_loss_class: 0.0360 - kl_loss: 0.0014 - kl_div: 12.1888 - val_loss: 0.0236 - val_reconstruction_loss_cont: 0.0104 - val_reconstruction_loss_class: 0.0123 - val_kl_loss: 9.7577e-04 - val_mean_abs_diff_cont: 0.0430 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.7662 - val_loss_sample: 0.0105 - val_reconstruction_loss_cont_sample: 0.0105 - val_reconstruction_loss_class_sample: 0.0131 - val_mean_abs_diff_cont_sample: 0.0425 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8187
# --- Starting trial: run-20
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.9733 - reconstruction_loss_cont: 0.0512 - reconstruction_loss_class: 0.0369 - kl_loss: 0.0205 - kl_div: 12.3904 - val_loss: 0.1255 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0112 - val_kl_loss: 0.0027 - val_mean_abs_diff_cont: 0.0465 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.9979 - val_loss_sample: 0.0109 - val_reconstruction_loss_cont_sample: 0.0109 - val_reconstruction_loss_class_sample: 0.0120 - val_mean_abs_diff_cont_sample: 0.0450 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9258
# --- Starting trial: run-21
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0961 - reconstruction_loss_cont: 0.0418 - reconstruction_loss_class: 0.0684 - kl_loss: 8.0850e-04 - kl_div: 12.0478 - val_loss: 0.0126 - val_reconstruction_loss_cont: 0.0103 - val_reconstruction_loss_class: 0.0120 - val_kl_loss: 1.1543e-04 - val_mean_abs_diff_cont: 0.0413 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.7138 - val_loss_sample: 0.0103 - val_reconstruction_loss_cont_sample: 0.0103 - val_reconstruction_loss_class_sample: 0.0118 - val_mean_abs_diff_cont_sample: 0.0413 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8050
# --- Starting trial: run-22
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1786 - reconstruction_loss_cont: 0.0469 - reconstruction_loss_class: 0.0395 - kl_loss: 8.9190e-04 - kl_div: 12.1845 - val_loss: 0.0268 - val_reconstruction_loss_cont: 0.0112 - val_reconstruction_loss_class: 0.0119 - val_kl_loss: 3.6634e-04 - val_mean_abs_diff_cont: 0.0451 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.8314 - val_loss_sample: 0.0113 - val_reconstruction_loss_cont_sample: 0.0113 - val_reconstruction_loss_class_sample: 0.0121 - val_mean_abs_diff_cont_sample: 0.0451 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8294
# --- Starting trial: run-23
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': False, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.9538 - reconstruction_loss_cont: 0.0590 - reconstruction_loss_class: 0.0363 - kl_loss: 0.0013 - kl_div: 14.8918 - val_loss: 0.1338 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0117 - val_kl_loss: 5.6152e-04 - val_mean_abs_diff_cont: 0.0491 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.2582 - val_loss_sample: 0.0110 - val_reconstruction_loss_cont_sample: 0.0110 - val_reconstruction_loss_class_sample: 0.0134 - val_mean_abs_diff_cont_sample: 0.0497 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8670
# --- Starting trial: run-24
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0499 - reconstruction_loss_cont: 0.0375 - reconstruction_loss_class: 0.0373 - kl_loss: 6.3377 - kl_div: 11.0254 - val_loss: 0.0104 - val_reconstruction_loss_cont: 0.0095 - val_reconstruction_loss_class: 0.0023 - val_kl_loss: 6.5526 - val_mean_abs_diff_cont: 0.0430 - val_mean_abs_diff_class: 0.0018 - val_mean_binary_value: 3.1566e-04 - val_kl_div: 1.5205 - val_loss_sample: 0.1505 - val_reconstruction_loss_cont_sample: 0.1505 - val_reconstruction_loss_class_sample: 0.4121 - val_mean_abs_diff_cont_sample: 0.3312 - val_mean_abs_diff_class_sample: 0.0327 - val_mean_binary_value_sample: 0.0312 - val_kl_div_sample: 30.5754
# --- Starting trial: run-25
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1298 - reconstruction_loss_cont: 0.0539 - reconstruction_loss_class: 0.0208 - kl_loss: 10.4602 - kl_div: 16.8445 - val_loss: 0.0124 - val_reconstruction_loss_cont: 0.0107 - val_reconstruction_loss_class: 7.7770e-04 - val_kl_loss: 9.0795 - val_mean_abs_diff_cont: 0.0475 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 2.5873 - val_loss_sample: 0.1299 - val_reconstruction_loss_cont_sample: 0.1299 - val_reconstruction_loss_class_sample: 0.5721 - val_mean_abs_diff_cont_sample: 0.3094 - val_mean_abs_diff_class_sample: 0.3754 - val_mean_binary_value_sample: 0.3750 - val_kl_div_sample: 23.6877
# --- Starting trial: run-26
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.9073 - reconstruction_loss_cont: 0.0534 - reconstruction_loss_class: 0.0246 - kl_loss: 11.7180 - kl_div: 13.7693 - val_loss: 0.0159 - val_reconstruction_loss_cont: 0.0118 - val_reconstruction_loss_class: 2.5276e-04 - val_kl_loss: 15.7659 - val_mean_abs_diff_cont: 0.0534 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 1.7840 - val_loss_sample: 0.2204 - val_reconstruction_loss_cont_sample: 0.2204 - val_reconstruction_loss_class_sample: 0.4931 - val_mean_abs_diff_cont_sample: 0.4275 - val_mean_abs_diff_class_sample: 0.3131 - val_mean_binary_value_sample: 0.3125 - val_kl_div_sample: 51.6299
# --- Starting trial: run-27
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0749 - reconstruction_loss_cont: 0.0515 - reconstruction_loss_class: 0.0873 - kl_loss: 0.0058 - kl_div: 13.9059 - val_loss: 0.0119 - val_reconstruction_loss_cont: 0.0106 - val_reconstruction_loss_class: 0.0129 - val_kl_loss: 2.7360e-04 - val_mean_abs_diff_cont: 0.0432 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.0564 - val_loss_sample: 0.0107 - val_reconstruction_loss_cont_sample: 0.0107 - val_reconstruction_loss_class_sample: 0.0132 - val_mean_abs_diff_cont_sample: 0.0434 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9087
# --- Starting trial: run-28
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.2081 - reconstruction_loss_cont: 0.0515 - reconstruction_loss_class: 0.0439 - kl_loss: 0.1926 - kl_div: 13.9088 - val_loss: 0.0205 - val_reconstruction_loss_cont: 0.0108 - val_reconstruction_loss_class: 0.0093 - val_kl_loss: 0.0042 - val_mean_abs_diff_cont: 0.0456 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.0686 - val_loss_sample: 0.0107 - val_reconstruction_loss_cont_sample: 0.0107 - val_reconstruction_loss_class_sample: 0.0133 - val_mean_abs_diff_cont_sample: 0.0456 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8208
# --- Starting trial: run-29
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 1.0736 - reconstruction_loss_cont: 0.0612 - reconstruction_loss_class: 0.0248 - kl_loss: 1.3458 - kl_div: 18.3138 - val_loss: 0.0892 - val_reconstruction_loss_cont: 0.0125 - val_reconstruction_loss_class: 9.6205e-04 - val_kl_loss: 0.6710 - val_mean_abs_diff_cont: 0.0571 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 2.7265 - val_loss_sample: 0.0267 - val_reconstruction_loss_cont_sample: 0.0267 - val_reconstruction_loss_class_sample: 0.1011 - val_mean_abs_diff_cont_sample: 0.1089 - val_mean_abs_diff_class_sample: 0.0327 - val_mean_binary_value_sample: 0.0312 - val_kl_div_sample: 3.8229
# --- Starting trial: run-30
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0670 - reconstruction_loss_cont: 0.0455 - reconstruction_loss_class: 0.0771 - kl_loss: 5.5117e-04 - kl_div: 10.9364 - val_loss: 0.0120 - val_reconstruction_loss_cont: 0.0105 - val_reconstruction_loss_class: 0.0130 - val_kl_loss: 1.5129e-04 - val_mean_abs_diff_cont: 0.0438 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.7706 - val_loss_sample: 0.0104 - val_reconstruction_loss_cont_sample: 0.0104 - val_reconstruction_loss_class_sample: 0.0135 - val_mean_abs_diff_cont_sample: 0.0435 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8658
# --- Starting trial: run-31
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.2245 - reconstruction_loss_cont: 0.0578 - reconstruction_loss_class: 0.0644 - kl_loss: 9.8772e-04 - kl_div: 14.4344 - val_loss: 0.0228 - val_reconstruction_loss_cont: 0.0105 - val_reconstruction_loss_class: 0.0120 - val_kl_loss: 2.7739e-04 - val_mean_abs_diff_cont: 0.0452 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.1627 - val_loss_sample: 0.0104 - val_reconstruction_loss_cont_sample: 0.0104 - val_reconstruction_loss_class_sample: 0.0126 - val_mean_abs_diff_cont_sample: 0.0442 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8401
# --- Starting trial: run-32
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 1.1658 - reconstruction_loss_cont: 0.0579 - reconstruction_loss_class: 0.0424 - kl_loss: 0.0338 - kl_div: 13.5461 - val_loss: 0.1229 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0108 - val_kl_loss: 0.0036 - val_mean_abs_diff_cont: 0.0471 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.1656 - val_loss_sample: 0.0112 - val_reconstruction_loss_cont_sample: 0.0112 - val_reconstruction_loss_class_sample: 0.0121 - val_mean_abs_diff_cont_sample: 0.0478 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8986
# --- Starting trial: run-33
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0736 - reconstruction_loss_cont: 0.0473 - reconstruction_loss_class: 0.0816 - kl_loss: 1.5045e-04 - kl_div: 11.6201 - val_loss: 0.0147 - val_reconstruction_loss_cont: 0.0108 - val_reconstruction_loss_class: 0.0136 - val_kl_loss: 2.4884e-04 - val_mean_abs_diff_cont: 0.0444 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.8039 - val_loss_sample: 0.0109 - val_reconstruction_loss_cont_sample: 0.0109 - val_reconstruction_loss_class_sample: 0.0137 - val_mean_abs_diff_cont_sample: 0.0441 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9891
# --- Starting trial: run-34
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.2357 - reconstruction_loss_cont: 0.0613 - reconstruction_loss_class: 0.0651 - kl_loss: 2.4259e-04 - kl_div: 15.8505 - val_loss: 0.0243 - val_reconstruction_loss_cont: 0.0112 - val_reconstruction_loss_class: 0.0124 - val_kl_loss: 6.0476e-05 - val_mean_abs_diff_cont: 0.0462 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.4462 - val_loss_sample: 0.0113 - val_reconstruction_loss_cont_sample: 0.0113 - val_reconstruction_loss_class_sample: 0.0125 - val_mean_abs_diff_cont_sample: 0.0466 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.0121
# --- Starting trial: run-35
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 1.6308 - reconstruction_loss_cont: 0.0688 - reconstruction_loss_class: 0.0599 - kl_loss: 9.9316e-04 - kl_div: 18.3617 - val_loss: 0.1329 - val_reconstruction_loss_cont: 0.0105 - val_reconstruction_loss_class: 0.0120 - val_kl_loss: 2.6888e-04 - val_mean_abs_diff_cont: 0.0486 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.7716 - val_loss_sample: 0.0105 - val_reconstruction_loss_cont_sample: 0.0105 - val_reconstruction_loss_class_sample: 0.0124 - val_mean_abs_diff_cont_sample: 0.0478 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8898
# --- Starting trial: run-36
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0418 - reconstruction_loss_cont: 0.0290 - reconstruction_loss_class: 0.0363 - kl_loss: 4.9288 - kl_div: 7.2601 - val_loss: 0.0103 - val_reconstruction_loss_cont: 0.0099 - val_reconstruction_loss_class: 0.0012 - val_kl_loss: 3.3869 - val_mean_abs_diff_cont: 0.0407 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 1.2139 - val_loss_sample: 0.0458 - val_reconstruction_loss_cont_sample: 0.0458 - val_reconstruction_loss_class_sample: 0.4373 - val_mean_abs_diff_cont_sample: 0.1711 - val_mean_abs_diff_class_sample: 0.2819 - val_mean_binary_value_sample: 0.2812 - val_kl_div_sample: 5.9576
# --- Starting trial: run-37
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1142 - reconstruction_loss_cont: 0.0465 - reconstruction_loss_class: 0.0211 - kl_loss: 5.0183 - kl_div: 11.9037 - val_loss: 0.0130 - val_reconstruction_loss_cont: 0.0114 - val_reconstruction_loss_class: 9.6121e-04 - val_kl_loss: 6.2677 - val_mean_abs_diff_cont: 0.0530 - val_mean_abs_diff_class: 0.0028 - val_mean_binary_value: 0.0014 - val_kl_div: 1.4808 - val_loss_sample: 0.0647 - val_reconstruction_loss_cont_sample: 0.0647 - val_reconstruction_loss_class_sample: 0.5198 - val_mean_abs_diff_cont_sample: 0.1970 - val_mean_abs_diff_class_sample: 0.3442 - val_mean_binary_value_sample: 0.3438 - val_kl_div_sample: 7.3058
# --- Starting trial: run-38
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.8450 - reconstruction_loss_cont: 0.0820 - reconstruction_loss_class: 0.0244 - kl_loss: 4.0947 - kl_div: 21.1194 - val_loss: 0.0226 - val_reconstruction_loss_cont: 0.0107 - val_reconstruction_loss_class: 0.0011 - val_kl_loss: 5.1437 - val_mean_abs_diff_cont: 0.0524 - val_mean_abs_diff_class: 0.0026 - val_mean_binary_value: 0.0012 - val_kl_div: 2.6996 - val_loss_sample: 0.1340 - val_reconstruction_loss_cont_sample: 0.1340 - val_reconstruction_loss_class_sample: 0.4201 - val_mean_abs_diff_cont_sample: 0.3195 - val_mean_abs_diff_class_sample: 0.3442 - val_mean_binary_value_sample: 0.3438 - val_kl_div_sample: 22.1594
# --- Starting trial: run-39
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0539 - reconstruction_loss_cont: 0.0375 - reconstruction_loss_class: 0.0572 - kl_loss: 0.0044 - kl_div: 9.7935 - val_loss: 0.0121 - val_reconstruction_loss_cont: 0.0107 - val_reconstruction_loss_class: 0.0131 - val_kl_loss: 6.2755e-04 - val_mean_abs_diff_cont: 0.0418 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.5616 - val_loss_sample: 0.0108 - val_reconstruction_loss_cont_sample: 0.0108 - val_reconstruction_loss_class_sample: 0.0135 - val_mean_abs_diff_cont_sample: 0.0414 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9688
# --- Starting trial: run-40
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1365 - reconstruction_loss_cont: 0.0385 - reconstruction_loss_class: 0.0352 - kl_loss: 0.0484 - kl_div: 9.0507 - val_loss: 0.0213 - val_reconstruction_loss_cont: 0.0108 - val_reconstruction_loss_class: 0.0102 - val_kl_loss: 0.0027 - val_mean_abs_diff_cont: 0.0434 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.5373 - val_loss_sample: 0.0108 - val_reconstruction_loss_cont_sample: 0.0108 - val_reconstruction_loss_class_sample: 0.0135 - val_mean_abs_diff_cont_sample: 0.0433 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.1219
# --- Starting trial: run-41
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.8909 - reconstruction_loss_cont: 0.0515 - reconstruction_loss_class: 0.0196 - kl_loss: 0.7648 - kl_div: 10.6018 - val_loss: 0.0385 - val_reconstruction_loss_cont: 0.0112 - val_reconstruction_loss_class: 3.4216e-04 - val_kl_loss: 0.2390 - val_mean_abs_diff_cont: 0.0467 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 1.8975 - val_loss_sample: 0.0122 - val_reconstruction_loss_cont_sample: 0.0122 - val_reconstruction_loss_class_sample: 0.0361 - val_mean_abs_diff_cont_sample: 0.0562 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.2758
# --- Starting trial: run-42
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 5s 4ms/step - loss: 0.0557 - reconstruction_loss_cont: 0.0417 - reconstruction_loss_class: 0.0508 - kl_loss: 2.9652e-04 - kl_div: 11.0463 - val_loss: 0.0117 - val_reconstruction_loss_cont: 0.0104 - val_reconstruction_loss_class: 0.0123 - val_kl_loss: 9.8391e-05 - val_mean_abs_diff_cont: 0.0411 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.6503 - val_loss_sample: 0.0104 - val_reconstruction_loss_cont_sample: 0.0104 - val_reconstruction_loss_class_sample: 0.0124 - val_mean_abs_diff_cont_sample: 0.0413 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8966
# --- Starting trial: run-43
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.1438 - reconstruction_loss_cont: 0.0459 - reconstruction_loss_class: 0.0392 - kl_loss: 0.0011 - kl_div: 10.9370 - val_loss: 0.0239 - val_reconstruction_loss_cont: 0.0109 - val_reconstruction_loss_class: 0.0119 - val_kl_loss: 0.0011 - val_mean_abs_diff_cont: 0.0436 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.7361 - val_loss_sample: 0.0109 - val_reconstruction_loss_cont_sample: 0.0109 - val_reconstruction_loss_class_sample: 0.0129 - val_mean_abs_diff_cont_sample: 0.0440 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9641
# --- Starting trial: run-44
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.9812 - reconstruction_loss_cont: 0.0675 - reconstruction_loss_class: 0.0347 - kl_loss: 0.0160 - kl_div: 15.9755 - val_loss: 0.1171 - val_reconstruction_loss_cont: 0.0104 - val_reconstruction_loss_class: 0.0102 - val_kl_loss: 0.0048 - val_mean_abs_diff_cont: 0.0465 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.5583 - val_loss_sample: 0.0106 - val_reconstruction_loss_cont_sample: 0.0106 - val_reconstruction_loss_class_sample: 0.0123 - val_mean_abs_diff_cont_sample: 0.0478 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9557
# --- Starting trial: run-45
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0607 - reconstruction_loss_cont: 0.0388 - reconstruction_loss_class: 0.0528 - kl_loss: 1.6028e-04 - kl_div: 9.5797 - val_loss: 0.0124 - val_reconstruction_loss_cont: 0.0104 - val_reconstruction_loss_class: 0.0122 - val_kl_loss: 7.2117e-05 - val_mean_abs_diff_cont: 0.0411 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.4653 - val_loss_sample: 0.0105 - val_reconstruction_loss_cont_sample: 0.0105 - val_reconstruction_loss_class_sample: 0.0124 - val_mean_abs_diff_cont_sample: 0.0417 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8231
# --- Starting trial: run-46
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.2159 - reconstruction_loss_cont: 0.0487 - reconstruction_loss_class: 0.0414 - kl_loss: 0.0011 - kl_div: 13.2722 - val_loss: 0.0254 - val_reconstruction_loss_cont: 0.0105 - val_reconstruction_loss_class: 0.0118 - val_kl_loss: 3.0739e-04 - val_mean_abs_diff_cont: 0.0430 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.9069 - val_loss_sample: 0.0106 - val_reconstruction_loss_cont_sample: 0.0106 - val_reconstruction_loss_class_sample: 0.0119 - val_mean_abs_diff_cont_sample: 0.0431 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8903
# --- Starting trial: run-47
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 64, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 5s 4ms/step - loss: 1.0543 - reconstruction_loss_cont: 0.0576 - reconstruction_loss_class: 0.0392 - kl_loss: 0.0011 - kl_div: 12.6751 - val_loss: 0.1339 - val_reconstruction_loss_cont: 0.0106 - val_reconstruction_loss_class: 0.0116 - val_kl_loss: 7.3570e-04 - val_mean_abs_diff_cont: 0.0449 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 2.0302 - val_loss_sample: 0.0105 - val_reconstruction_loss_cont_sample: 0.0105 - val_reconstruction_loss_class_sample: 0.0130 - val_mean_abs_diff_cont_sample: 0.0438 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9096
# --- Starting trial: run-48
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.0491 - reconstruction_loss_cont: 0.0341 - reconstruction_loss_class: 0.0488 - kl_loss: 4.8195 - kl_div: 8.5819 - val_loss: 0.0119 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0045 - val_kl_loss: 4.0150 - val_mean_abs_diff_cont: 0.0424 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.4272 - val_loss_sample: 0.0421 - val_reconstruction_loss_cont_sample: 0.0421 - val_reconstruction_loss_class_sample: 0.1543 - val_mean_abs_diff_cont_sample: 0.1613 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 4.2684
# --- Starting trial: run-49
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.1373 - reconstruction_loss_cont: 0.0408 - reconstruction_loss_class: 0.0330 - kl_loss: 2.5401 - kl_div: 8.6521 - val_loss: 0.0143 - val_reconstruction_loss_cont: 0.0110 - val_reconstruction_loss_class: 0.0031 - val_kl_loss: 2.3047 - val_mean_abs_diff_cont: 0.0437 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.4085 - val_loss_sample: 0.0548 - val_reconstruction_loss_cont_sample: 0.0548 - val_reconstruction_loss_class_sample: 0.2375 - val_mean_abs_diff_cont_sample: 0.1811 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 6.4727
# --- Starting trial: run-50
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.8076 - reconstruction_loss_cont: 0.0487 - reconstruction_loss_class: 0.0264 - kl_loss: 5.7052 - kl_div: 12.3857 - val_loss: 0.0369 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0025 - val_kl_loss: 4.4495 - val_mean_abs_diff_cont: 0.0515 - val_mean_abs_diff_class: 0.0019 - val_mean_binary_value: 3.8580e-04 - val_kl_div: 1.8075 - val_loss_sample: 0.1613 - val_reconstruction_loss_cont_sample: 0.1613 - val_reconstruction_loss_class_sample: 0.2714 - val_mean_abs_diff_cont_sample: 0.3401 - val_mean_abs_diff_class_sample: 0.0639 - val_mean_binary_value_sample: 0.0625 - val_kl_div_sample: 25.1469
# --- Starting trial: run-51
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 4ms/step - loss: 0.0579 - reconstruction_loss_cont: 0.0386 - reconstruction_loss_class: 0.0653 - kl_loss: 0.0082 - kl_div: 9.9411 - val_loss: 0.0121 - val_reconstruction_loss_cont: 0.0108 - val_reconstruction_loss_class: 0.0123 - val_kl_loss: 7.5191e-04 - val_mean_abs_diff_cont: 0.0421 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.5388 - val_loss_sample: 0.0108 - val_reconstruction_loss_cont_sample: 0.0108 - val_reconstruction_loss_class_sample: 0.0130 - val_mean_abs_diff_cont_sample: 0.0418 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9670
# --- Starting trial: run-52
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.1704 - reconstruction_loss_cont: 0.0391 - reconstruction_loss_class: 0.0440 - kl_loss: 0.0640 - kl_div: 8.9242 - val_loss: 0.0216 - val_reconstruction_loss_cont: 0.0104 - val_reconstruction_loss_class: 0.0109 - val_kl_loss: 0.0028 - val_mean_abs_diff_cont: 0.0433 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.4068 - val_loss_sample: 0.0105 - val_reconstruction_loss_cont_sample: 0.0105 - val_reconstruction_loss_class_sample: 0.0125 - val_mean_abs_diff_cont_sample: 0.0438 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.7822
# --- Starting trial: run-53
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.8842 - reconstruction_loss_cont: 0.0440 - reconstruction_loss_class: 0.0227 - kl_loss: 0.9718 - kl_div: 11.5097 - val_loss: 0.0653 - val_reconstruction_loss_cont: 0.0099 - val_reconstruction_loss_class: 0.0015 - val_kl_loss: 0.4081 - val_mean_abs_diff_cont: 0.0429 - val_mean_abs_diff_class: 0.0029 - val_mean_binary_value: 0.0015 - val_kl_div: 1.7243 - val_loss_sample: 0.0191 - val_reconstruction_loss_cont_sample: 0.0191 - val_reconstruction_loss_class_sample: 0.2984 - val_mean_abs_diff_cont_sample: 0.0826 - val_mean_abs_diff_class_sample: 0.1262 - val_mean_binary_value_sample: 0.1250 - val_kl_div_sample: 2.3007
# --- Starting trial: run-54
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 4s 3ms/step - loss: 0.0743 - reconstruction_loss_cont: 0.0404 - reconstruction_loss_class: 0.0697 - kl_loss: 0.0032 - kl_div: 10.4473 - val_loss: 0.0127 - val_reconstruction_loss_cont: 0.0111 - val_reconstruction_loss_class: 0.0129 - val_kl_loss: 2.6578e-04 - val_mean_abs_diff_cont: 0.0431 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.6314 - val_loss_sample: 0.0112 - val_reconstruction_loss_cont_sample: 0.0112 - val_reconstruction_loss_class_sample: 0.0128 - val_mean_abs_diff_cont_sample: 0.0433 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9885
# --- Starting trial: run-55
# {'num_embedded': 2, 'num_units': 64, 'num_units1': 128, 'bool_layer_2': False, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# ...
# --- Starting trial: run-3822
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 15s 16ms/step - loss: 0.0482 - reconstruction_loss_cont: 0.0379 - reconstruction_loss_class: 0.0318 - kl_loss: 8.6767e-04 - kl_div: 5.1208 - val_loss: 0.0144 - val_reconstruction_loss_cont: 0.0133 - val_reconstruction_loss_class: 0.0097 - val_kl_loss: 1.1551e-04 - val_mean_abs_diff_cont: 0.0642 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.3671 - val_loss_sample: 0.0130 - val_reconstruction_loss_cont_sample: 0.0130 - val_reconstruction_loss_class_sample: 0.0132 - val_mean_abs_diff_cont_sample: 0.0635 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.2347
# --- Starting trial: run-3823
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 15s 16ms/step - loss: 0.0870 - reconstruction_loss_cont: 0.0440 - reconstruction_loss_class: 0.0094 - kl_loss: 0.0047 - kl_div: 5.9868 - val_loss: 0.0160 - val_reconstruction_loss_cont: 0.0143 - val_reconstruction_loss_class: 9.9817e-04 - val_kl_loss: 6.9727e-04 - val_mean_abs_diff_cont: 0.0707 - val_mean_abs_diff_class: 0.0028 - val_mean_binary_value: 0.0014 - val_kl_div: 1.5984 - val_loss_sample: 0.0145 - val_reconstruction_loss_cont_sample: 0.0145 - val_reconstruction_loss_class_sample: 0.0139 - val_mean_abs_diff_cont_sample: 0.0695 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.6336
# --- Starting trial: run-3824
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 15s 15ms/step - loss: 0.3425 - reconstruction_loss_cont: 0.0576 - reconstruction_loss_class: 0.0063 - kl_loss: 0.0336 - kl_div: 7.4850 - val_loss: 0.0242 - val_reconstruction_loss_cont: 0.0179 - val_reconstruction_loss_class: 3.3577e-04 - val_kl_loss: 0.0029 - val_mean_abs_diff_cont: 0.0906 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 2.0189 - val_loss_sample: 0.0185 - val_reconstruction_loss_cont_sample: 0.0185 - val_reconstruction_loss_class_sample: 0.0147 - val_mean_abs_diff_cont_sample: 0.0923 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.4194
# --- Starting trial: run-3825
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 15s 15ms/step - loss: 0.0485 - reconstruction_loss_cont: 0.0402 - reconstruction_loss_class: 0.0317 - kl_loss: 3.3190e-05 - kl_div: 5.3277 - val_loss: 0.0146 - val_reconstruction_loss_cont: 0.0133 - val_reconstruction_loss_class: 0.0122 - val_kl_loss: 3.8212e-06 - val_mean_abs_diff_cont: 0.0647 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.3092 - val_loss_sample: 0.0132 - val_reconstruction_loss_cont_sample: 0.0132 - val_reconstruction_loss_class_sample: 0.0121 - val_mean_abs_diff_cont_sample: 0.0650 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8813
# --- Starting trial: run-3826
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 14s 15ms/step - loss: 0.1023 - reconstruction_loss_cont: 0.0499 - reconstruction_loss_class: 0.0197 - kl_loss: 4.6697e-04 - kl_div: 6.8860 - val_loss: 0.0218 - val_reconstruction_loss_cont: 0.0156 - val_reconstruction_loss_class: 0.0029 - val_kl_loss: 3.3264e-04 - val_mean_abs_diff_cont: 0.0747 - val_mean_abs_diff_class: 0.0029 - val_mean_binary_value: 0.0014 - val_kl_div: 1.8129 - val_loss_sample: 0.0161 - val_reconstruction_loss_cont_sample: 0.0161 - val_reconstruction_loss_class_sample: 0.0167 - val_mean_abs_diff_cont_sample: 0.0766 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.1341
# --- Starting trial: run-3827
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': False, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 14s 15ms/step - loss: 0.5347 - reconstruction_loss_cont: 0.0617 - reconstruction_loss_class: 0.0102 - kl_loss: 0.0049 - kl_div: 8.5108 - val_loss: 0.0363 - val_reconstruction_loss_cont: 0.0165 - val_reconstruction_loss_class: 6.1333e-04 - val_kl_loss: 0.0014 - val_mean_abs_diff_cont: 0.0844 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0016 - val_kl_div: 2.1477 - val_loss_sample: 0.0151 - val_reconstruction_loss_cont_sample: 0.0151 - val_reconstruction_loss_class_sample: 0.0203 - val_mean_abs_diff_cont_sample: 0.0781 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.2973
# --- Starting trial: run-3828
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 16s 17ms/step - loss: 0.0150 - reconstruction_loss_cont: 0.0112 - reconstruction_loss_class: 0.0098 - kl_loss: 2.5521 - kl_div: 1.8516 - val_loss: 0.0068 - val_reconstruction_loss_cont: 0.0065 - val_reconstruction_loss_class: 2.5115e-04 - val_kl_loss: 2.9409 - val_mean_abs_diff_cont: 0.0383 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 0.4007 - val_loss_sample: 0.0789 - val_reconstruction_loss_cont_sample: 0.0789 - val_reconstruction_loss_class_sample: 0.0136 - val_mean_abs_diff_cont_sample: 0.2276 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: -1.3845
# --- Starting trial: run-3829
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 15s 16ms/step - loss: 0.0382 - reconstruction_loss_cont: 0.0160 - reconstruction_loss_class: 0.0064 - kl_loss: 2.4864 - kl_div: 2.4743 - val_loss: 0.0079 - val_reconstruction_loss_cont: 0.0076 - val_reconstruction_loss_class: 4.2576e-05 - val_kl_loss: 2.8587 - val_mean_abs_diff_cont: 0.0418 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 0.6284 - val_loss_sample: 0.0660 - val_reconstruction_loss_cont_sample: 0.0660 - val_reconstruction_loss_class_sample: 0.0190 - val_mean_abs_diff_cont_sample: 0.1980 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 3.1813
# --- Starting trial: run-3830
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.0001, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 18s 19ms/step - loss: 0.2320 - reconstruction_loss_cont: 0.0372 - reconstruction_loss_class: 0.0064 - kl_loss: 1.5966 - kl_div: 5.3365 - val_loss: 0.0101 - val_reconstruction_loss_cont: 0.0098 - val_reconstruction_loss_class: 2.9942e-06 - val_kl_loss: 2.6488 - val_mean_abs_diff_cont: 0.0442 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 0.9454 - val_loss_sample: 0.1334 - val_reconstruction_loss_cont_sample: 0.1334 - val_reconstruction_loss_class_sample: 0.1306 - val_mean_abs_diff_cont_sample: 0.3140 - val_mean_abs_diff_class_sample: 0.0327 - val_mean_binary_value_sample: 0.0312 - val_kl_div_sample: 28.0527
# --- Starting trial: run-3831
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 17s 19ms/step - loss: 0.0223 - reconstruction_loss_cont: 0.0174 - reconstruction_loss_class: 0.0175 - kl_loss: 0.0037 - kl_div: 2.3332 - val_loss: 0.0120 - val_reconstruction_loss_cont: 0.0117 - val_reconstruction_loss_class: 0.0011 - val_kl_loss: 0.0017 - val_mean_abs_diff_cont: 0.0546 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 0.6692 - val_loss_sample: 0.0115 - val_reconstruction_loss_cont_sample: 0.0115 - val_reconstruction_loss_class_sample: 0.0138 - val_mean_abs_diff_cont_sample: 0.0534 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.6973
# --- Starting trial: run-3832
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 17s 18ms/step - loss: 0.0483 - reconstruction_loss_cont: 0.0231 - reconstruction_loss_class: 0.0077 - kl_loss: 0.0084 - kl_div: 3.4939 - val_loss: 0.0114 - val_reconstruction_loss_cont: 0.0112 - val_reconstruction_loss_class: 8.3987e-05 - val_kl_loss: 0.0013 - val_mean_abs_diff_cont: 0.0566 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 0.8798 - val_loss_sample: 0.0112 - val_reconstruction_loss_cont_sample: 0.0112 - val_reconstruction_loss_class_sample: 0.0171 - val_mean_abs_diff_cont_sample: 0.0556 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.8679
# --- Starting trial: run-3833
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 0.1, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 17s 18ms/step - loss: 0.2647 - reconstruction_loss_cont: 0.0375 - reconstruction_loss_class: 0.0080 - kl_loss: 0.0675 - kl_div: 4.8434 - val_loss: 0.0163 - val_reconstruction_loss_cont: 0.0137 - val_reconstruction_loss_class: 1.0475e-04 - val_kl_loss: 0.0155 - val_mean_abs_diff_cont: 0.0762 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 1.4357 - val_loss_sample: 0.0150 - val_reconstruction_loss_cont_sample: 0.0150 - val_reconstruction_loss_class_sample: 0.0177 - val_mean_abs_diff_cont_sample: 0.0816 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.7354
# --- Starting trial: run-3834
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 16s 17ms/step - loss: 0.0218 - reconstruction_loss_cont: 0.0168 - reconstruction_loss_class: 0.0240 - kl_loss: 2.6177e-04 - kl_div: 2.1038 - val_loss: 0.0126 - val_reconstruction_loss_cont: 0.0114 - val_reconstruction_loss_class: 0.0109 - val_kl_loss: 3.8437e-05 - val_mean_abs_diff_cont: 0.0533 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 0.6210 - val_loss_sample: 0.0112 - val_reconstruction_loss_cont_sample: 0.0112 - val_reconstruction_loss_class_sample: 0.0119 - val_mean_abs_diff_cont_sample: 0.0508 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.7853
# --- Starting trial: run-3835
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 16s 17ms/step - loss: 0.0471 - reconstruction_loss_cont: 0.0230 - reconstruction_loss_class: 0.0084 - kl_loss: 0.0023 - kl_div: 3.0592 - val_loss: 0.0139 - val_reconstruction_loss_cont: 0.0116 - val_reconstruction_loss_class: 5.7946e-04 - val_kl_loss: 0.0018 - val_mean_abs_diff_cont: 0.0581 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0016 - val_kl_div: 0.8320 - val_loss_sample: 0.0117 - val_reconstruction_loss_cont_sample: 0.0117 - val_reconstruction_loss_class_sample: 0.0210 - val_mean_abs_diff_cont_sample: 0.0587 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 0.9157
# --- Starting trial: run-3836
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 1.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 15s 16ms/step - loss: 0.3057 - reconstruction_loss_cont: 0.0394 - reconstruction_loss_class: 0.0078 - kl_loss: 0.0060 - kl_div: 5.5846 - val_loss: 0.0170 - val_reconstruction_loss_cont: 0.0153 - val_reconstruction_loss_class: 6.4070e-05 - val_kl_loss: 0.0011 - val_mean_abs_diff_cont: 0.0758 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 1.7962 - val_loss_sample: 0.0145 - val_reconstruction_loss_cont_sample: 0.0145 - val_reconstruction_loss_class_sample: 0.0214 - val_mean_abs_diff_cont_sample: 0.0708 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.9938
# --- Starting trial: run-3837
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 0.1}
# 890/890 [==============================] - 18s 19ms/step - loss: 0.0236 - reconstruction_loss_cont: 0.0179 - reconstruction_loss_class: 0.0257 - kl_loss: 3.3237e-05 - kl_div: 2.4256 - val_loss: 0.0129 - val_reconstruction_loss_cont: 0.0116 - val_reconstruction_loss_class: 0.0132 - val_kl_loss: 2.5681e-06 - val_mean_abs_diff_cont: 0.0535 - val_mean_abs_diff_class: 0.0015 - val_mean_binary_value: 0.0000e+00 - val_kl_div: 1.0068 - val_loss_sample: 0.0114 - val_reconstruction_loss_cont_sample: 0.0114 - val_reconstruction_loss_class_sample: 0.0126 - val_mean_abs_diff_cont_sample: 0.0522 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.2886
# --- Starting trial: run-3838
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 1.0}
# 890/890 [==============================] - 17s 18ms/step - loss: 0.0568 - reconstruction_loss_cont: 0.0246 - reconstruction_loss_class: 0.0145 - kl_loss: 4.3424e-04 - kl_div: 3.6329 - val_loss: 0.0196 - val_reconstruction_loss_cont: 0.0137 - val_reconstruction_loss_class: 0.0025 - val_kl_loss: 3.4225e-04 - val_mean_abs_diff_cont: 0.0629 - val_mean_abs_diff_class: 0.0032 - val_mean_binary_value: 0.0018 - val_kl_div: 1.0649 - val_loss_sample: 0.0140 - val_reconstruction_loss_cont_sample: 0.0140 - val_reconstruction_loss_class_sample: 0.0178 - val_mean_abs_diff_cont_sample: 0.0644 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.1809
# --- Starting trial: run-3839
# {'num_embedded': 64, 'num_units': 512, 'num_units1': 512, 'bool_layer_2': True, 'bool_layer_4': True, 'KL_LOSS_RATE': 10.0, 'BINARY_WEIGHT': 10.0}
# 890/890 [==============================] - 16s 17ms/step - loss: 0.2518 - reconstruction_loss_cont: 0.0376 - reconstruction_loss_class: 0.0077 - kl_loss: 0.0019 - kl_div: 5.2489 - val_loss: 0.0537 - val_reconstruction_loss_cont: 0.0156 - val_reconstruction_loss_class: 4.8095e-04 - val_kl_loss: 0.0033 - val_mean_abs_diff_cont: 0.0774 - val_mean_abs_diff_class: 0.0030 - val_mean_binary_value: 0.0015 - val_kl_div: 1.5730 - val_loss_sample: 0.0159 - val_reconstruction_loss_cont_sample: 0.0159 - val_reconstruction_loss_class_sample: 0.0257 - val_mean_abs_diff_cont_sample: 0.0754 - val_mean_abs_diff_class_sample: 0.0015 - val_mean_binary_value_sample: 0.0000e+00 - val_kl_div_sample: 1.8283
